# %% [markdown]
# # 🧩 Notebook 01: Setup, Styling, and First Visualizations in Seaborn

# %%
# 📦 Setup & Imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
from pathlib import Path

# ✅ Setup path to use utils
PROJECT_ROOT = Path.cwd().parent
UTILS_DIR = PROJECT_ROOT / "utils"
if str(UTILS_DIR) not in sys.path:
    sys.path.insert(0, str(UTILS_DIR))

# 🧰 Custom utilities
from plot_utils import (
    apply_theme,
    stylize_plot,
    add_reference_line,
    save_fig,
    annotate_points
)

# 🎨 Apply project-wide theme
apply_theme(style="whitegrid", context="notebook", palette="deep")

print("✅ Seaborn Project Utils Loaded")
# Out:
# ✅ Seaborn Project Utils Loaded

# %%
# Load and inspect built-in 'tips' dataset
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Histogram with KDE
plt.figure(figsize=(8, 5))
sns.histplot(data=tips, x="total_bill", kde=True, bins=20)

stylize_plot(
    title="Distribution of Total Bill",
    xlabel="Total Bill ($)",
    ylabel="Frequency"
)

save_fig("../exports/01_setup/tips_total_bill_histogram.png")
plt.show()
# Out:
# ✅ Plot saved to ../exports/01_setup/tips_total_bill_histogram.png

# %%
# Scatterplot with hue and style
plt.figure(figsize=(8, 5))
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="sex", style="smoker", s=100)

stylize_plot(
    title="Total Bill vs Tip by Gender & Smoking Status",
    xlabel="Total Bill ($)",
    ylabel="Tip ($)"
)

save_fig("../exports/01_setup/tips_bill_vs_tip_scatter.png")
plt.show()
# Out:
# ✅ Plot saved to ../exports/01_setup/tips_bill_vs_tip_scatter.png

# %%
# Load dummy sales dataset
sales = pd.read_csv("../datasets/sales_data.csv")
sales.head()
# Out:
#   Region     Product  Units Sold  Unit Price  Total Sales
# 0  North      Tablet          27      571.77     15437.79
# 1   West  Smartphone          28      428.59     12000.52
# 2  South     Monitor          33      271.51      8959.83
# 3  North  Smartphone          31      117.21      3633.51
# 4   West  Smartphone          33      566.33     18688.89

# %%
# Boxplot of Total Sales by Region
plt.figure(figsize=(8, 5))
sns.boxplot(data=sales, x="Region", y="Total Sales")

stylize_plot(
    title="Total Sales Distribution by Region",
    xlabel="Region",
    ylabel="Sales ($)"
)

add_reference_line(value=20000, axis='h', color="red")
save_fig("../exports/01_setup/sales_by_region_boxplot.png")
plt.show()
# Out:
# ✅ Plot saved to ../exports/01_setup/sales_by_region_boxplot.png

# %%
# Histogram of units sold
plt.figure(figsize=(8, 5))
sns.histplot(data=sales, x="Units Sold", hue="Region", multiple="stack", bins=20)

stylize_plot(
    title="Units Sold by Region",
    xlabel="Units Sold",
    ylabel="Count"
)

save_fig("../exports/01_setup/sales_units_sold_by_region.png")
plt.show()
# Out:
# ✅ Plot saved to ../exports/01_setup/sales_units_sold_by_region.png

# %% [markdown]
# ## ✅ Summary:
#
# - Applied Seaborn themes globally using `apply_theme()`
# - Loaded both built-in and custom datasets
# - Plotted histogram, scatterplot, and boxplot using utility functions
# - Saved plots directly to the project’s `exports/plots/` folder
#
# All future notebooks will follow the same pattern for modularity and clarity.
