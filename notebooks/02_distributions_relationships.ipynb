# %% [markdown]
# # 🧩 Notebook 02: Distribution and Relationship Plots in Seaborn

# %%
# 📦 Setup & Imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
from pathlib import Path

# ✅ Setup path to use utils
PROJECT_ROOT = Path.cwd().parent
UTILS_DIR = PROJECT_ROOT / "utils"
if str(UTILS_DIR) not in sys.path:
    sys.path.insert(0, str(UTILS_DIR))

# 🧰 Custom utilities
from plot_utils import (
    apply_theme,
    stylize_plot,
    add_reference_line,
    save_fig,
    annotate_points
)

# 🎨 Apply project-wide theme
apply_theme()

print("✅ Seaborn Project Utils Loaded")
# Out:
# ✅ Seaborn Project Utils Loaded

# %%
# Load tips dataset
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# 📊 Histogram + KDE

plt.figure(figsize=(8, 5))
sns.histplot(data=tips, x="total_bill", kde=True, bins=30)

stylize_plot(
    title="Histogram with KDE: Total Bill",
    xlabel="Total Bill ($)",
    ylabel="Density"
)

save_fig("../exports/02_distributions/dist_total_bill_kde.png")
plt.show()
# Out:
# ✅ Plot saved to ../exports/02_distributions/dist_total_bill_kde.png

# %%
# 📊 ECDF Plot
plt.figure(figsize=(8, 5))
sns.ecdfplot(data=tips, x="total_bill", hue="sex")

stylize_plot(
    title="ECDF: Total Bill by Gender",
    xlabel="Total Bill ($)",
    ylabel="Proportion"
)

save_fig("../exports/02_distributions/ecdf_total_bill.png")
plt.show()
# Out:
# ✅ Plot saved to ../exports/02_distributions/ecdf_total_bill.png

# %%
# 📊 Rug Plot (Layered)

plt.figure(figsize=(8, 5))
sns.kdeplot(data=tips, x="total_bill", fill=True)
sns.rugplot(data=tips, x="total_bill", height=0.05)

stylize_plot(
    title="KDE with Rugplot: Total Bill",
    xlabel="Total Bill ($)",
    ylabel="Density"
)

save_fig("../exports/02_distributions/kde_rug_total_bill.png")
plt.show()
# Out:
# ✅ Plot saved to ../exports/02_distributions/kde_rug_total_bill.png

# %%
# 📊 Scatterplot with hue, size, style

plt.figure(figsize=(8, 5))
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="time", size="size", style="sex")

stylize_plot(
    title="Scatterplot: Tip vs Total Bill",
    xlabel="Total Bill ($)",
    ylabel="Tip ($)"
)

save_fig("../exports/02_distributions/scatter_tip_vs_bill_size_time.png")
plt.show()
# Out:
# ✅ Plot saved to ../exports/02_distributions/scatter_tip_vs_bill_size_time.png

# %%
# 📈 Line Plot (Smoothed trend)

plt.figure(figsize=(8, 5))
sns.lineplot(data=tips, x="size", y="tip", ci="sd")

stylize_plot(
    title="Line Plot: Average Tip by Table Size",
    xlabel="Table Size",
    ylabel="Average Tip ($)"
)

save_fig("../exports/02_distributions/lineplot_tip_by_size.png")
plt.show()
# Out:
# ✅ Plot saved to ../exports/02_distributions/lineplot_tip_by_size.png
# /var/folders/23/phyj43kx4jz5gywlx6__9_kc0000gn/T/ipykernel_32777/4127506538.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.lineplot(data=tips, x="size", y="tip", ci="sd")

# %%
# 📈 Regression Plot + Residuals

plt.figure(figsize=(8, 5))
sns.regplot(data=tips, x="total_bill", y="tip", scatter=True, ci=95)

stylize_plot(
    title="Regression Plot: Tip vs Total Bill",
    xlabel="Total Bill ($)",
    ylabel="Tip ($)"
)

save_fig("../exports/02_distributions/regplot_tip_vs_bill.png")
plt.show()
# Out:
# ✅ Plot saved to ../exports/02_distributions/regplot_tip_vs_bill.png

# %%
# Residual Plot
plt.figure(figsize=(8, 5))
sns.residplot(data=tips, x="total_bill", y="tip")

stylize_plot(
    title="Residual Plot: Tip vs Total Bill",
    xlabel="Total Bill ($)",
    ylabel="Residuals"
)

save_fig("../exports/02_distributions/residplot_tip_vs_bill.png")
plt.show()
# Out:
# ✅ Plot saved to ../exports/02_distributions/residplot_tip_vs_bill.png

# %% [markdown]
# # ✅ Summary
#
# In this notebook, we:
#
# - Explored univariate and bivariate Seaborn plots
# - Used visual encodings (hue, style, size) to show subpopulations
# - Compared KDE vs Histogram vs ECDF vs Rugplot
# - Applied regplot and residplot for linear regression analysis
# - Continued applying modular plot utilities from `plot_utils.py`
